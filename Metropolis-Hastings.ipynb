# %%
import numpy as np
import matplotlib.pyplot as plt
from math import factorial

# %%
def poisson(k, param):
  # Return Poisson probability for k with parameter param
  return param ** k * np.exp(-param) / factorial(k)

# %%
poisson(5,3)
# Out:
# 0.10081881344492448

# %%
def geom(p):
  # Returns shifted sample from geometric distribution with probability p
  sample = np.random.geometric(p)
  return sample - 1

# %%
geom(0.5)
# Out:
# 1

# %%
def metropolis_step(i, param, p):
  proposed_j = geom(p)
  y = np.random.normal(0, 1)

  T_ij = p ** (proposed_j + 1)
  T_ji = p ** (i + 1)

  pi_i = poisson(i, param)
  pi_j = poisson(proposed_j, param)

  acceptance_ratio = (pi_j * T_ji)/(pi_i * T_ij)

  if acceptance_ratio >= np.random.uniform():
    return proposed_j

  return i

# %%
def metropolis_sampler(start, param = 3, p = 0.5, n = 1000, burn_in = 100000, lag = 10):

  current_state = start

  for i in range(burn_in):
    current_state = metropolis_step(current_state, param, p)

  results = []

  for i in range(n):
    for j in range(lag):
      current_state = metropolis_step(current_state, param, p)

    results.append(current_state)


  return np.array(results, dtype=int)

# %%
results = metropolis_sampler(0)

# %%
results
# Out:
# array([5, 4, 4, 3, 2, 3, 2, 5, 2, 6, 6, 2, 2, 6, 6, 6, 4, 1, 1, 4, 2, 2,
#        1, 2, 0, 6, 6, 3, 4, 1, 4, 4, 4, 1, 1, 2, 4, 2, 3, 2, 3, 1, 5, 0,
#        2, 3, 3, 3, 3, 1, 2, 2, 4, 1, 4, 1, 5, 3, 6, 2, 1, 2, 4, 4, 3, 1,
#        5, 5, 5, 5, 1, 2, 4, 3, 1, 3, 3, 1, 1, 2, 1, 2, 3, 3, 4, 1, 1, 3,
#        1, 3, 3, 4, 5, 3, 0, 3, 1, 4, 1, 0, 2, 1, 5, 2, 1, 3, 5, 2, 3, 0,
#        2, 3, 2, 1, 3, 4, 3, 1, 3, 3, 3, 5, 5, 5, 3, 4, 6, 1, 2, 2, 1, 1,
#        1, 2, 2, 2, 1, 3, 2, 4, 0, 2, 0, 1, 3, 2, 4, 5, 2, 5, 5, 1, 2, 6,
#        1, 2, 3, 6, 2, 0, 3, 5, 5, 5, 5, 5, 3, 3, 3, 2, 5, 1, 2, 3, 1, 2,
#        6, 6, 4, 2, 4, 1, 6, 6, 6, 4, 4, 6, 2, 6, 3, 7, 2, 2, 2, 2, 0, 3,
#        2, 4, 7, 2, 3, 2, 3, 3, 3, 2, 2, 2, 1, 2, 2, 7, 1, 4, 4, 2, 3, 3,
#        5, 5, 5, 5, 4, 4, 4, 3, 0, 1, 1, 2, 4, 3, 5, 5, 4, 4, 4, 3, 5, 5,
#        4, 4, 4, 2, 2, 4, 0, 3, 1, 4, 0, 1, 3, 2, 1, 2, 2, 1, 7, 7, 1, 2,
#        1, 4, 3, 3, 2, 5, 2, 2, 0, 2, 2, 3, 2, 2, 3, 1, 2, 4, 1, 3, 5, 5,
#        3, 3, 2, 4, 2, 0, 2, 4, 4, 0, 6, 6, 0, 1, 3, 3, 2, 3, 3, 1, 2, 1,
#        1, 4, 3, 1, 1, 2, 6, 2, 5, 2, 3, 4, 6, 2, 3, 1, 2, 3, 1, 5, 3, 3,
#        1, 3, 1, 4, 2, 3, 6, 6, 3, 7, 2, 3, 3, 3, 3, 2, 2, 1, 2, 2, 1, 2,
#        4, 0, 5, 3, 3, 3, 0, 4, 4, 1, 7, 7, 7, 2, 5, 2, 3, 2, 4, 1, 2, 5,
#        5, 2, 2, 0, 2, 4, 4, 3, 2, 0, 2, 1, 3, 4, 4, 2, 4, 5, 1, 1, 3, 0,
#        3, 5, 5, 3, 3, 1, 2, 1, 4, 0, 5, 1, 1, 4, 3, 3, 2, 4, 3, 1, 1, 1,
#        4, 7, 7, 7, 4, 4, 1, 5, 5, 5, 5, 4, 1, 3, 3, 3, 3, 3, 9, 4, 4, 3,
#        0, 5, 2, 5, 3, 3, 2, 2, 0, 1, 2, 5, 1, 3, 0, 4, 1, 2, 3, 0, 6, 5,
#        4, 4, 3, 5, 5, 3, 2, 1, 2, 1, 5, 4, 6, 6, 0, 0, 3, 2, 5, 3, 6, 0,
#        1, 2, 2, 1, 2, 2, 0, 2, 3, 2, 1, 3, 0, 3, 4, 2, 1, 3, 2, 6, 4, 3,
#        4, 6, 2, 2, 2, 1, 1, 3, 4, 7, 3, 2, 3, 2, 1, 4, 5, 4, 1, 2, 3, 3,
#        3, 4, 4, 3, 3, 4, 1, 3, 4, 4, 2, 7, 2, 5, 4, 4, 6, 4, 1, 4, 6, 5,
#        3, 3, 5, 4, 6, 5, 2, 2, 6, 2, 0, 2, 2, 4, 3, 3, 2, 6, 6, 6, 2, 1,
#        2, 6, 6, 6, 4, 3, 3, 2, 3, 2, 1, 1, 3, 4, 4, 6, 5, 2, 4, 2, 2, 3,
#        2, 2, 4, 4, 4, 3, 3, 4, 2, 2, 2, 3, 4, 2, 3, 3, 3, 5, 4, 4, 3, 4,
#        1, 3, 2, 2, 3, 3, 2, 1, 5, 5, 4, 3, 2, 2, 2, 3, 3, 3, 4, 1, 2, 2,
#        2, 3, 1, 0, 0, 2, 1, 7, 1, 1, 5, 2, 6, 6, 3, 3, 0, 2, 6, 6, 1, 1,
#        2, 1, 4, 4, 7, 6, 6, 2, 4, 7, 7, 1, 3, 4, 2, 2, 4, 4, 4, 2, 3, 2,
#        3, 4, 6, 6, 6, 6, 3, 3, 3, 2, 2, 4, 1, 4, 5, 5, 2, 2, 3, 4, 2, 3,
#        4, 4, 3, 6, 5, 3, 1, 2, 6, 1, 2, 2, 4, 5, 2, 3, 3, 2, 2, 2, 4, 5,
#        1, 4, 2, 3, 1, 1, 3, 6, 1, 3, 2, 5, 4, 5, 2, 2, 3, 4, 4, 1, 4, 4,
#        1, 3, 1, 5, 3, 5, 4, 5, 7, 3, 6, 6, 7, 2, 7, 1, 2, 1, 3, 5, 2, 0,
#        3, 2, 1, 3, 1, 1, 4, 6, 1, 1, 2, 1, 3, 1, 1, 2, 4, 2, 2, 2, 2, 1,
#        3, 4, 3, 2, 4, 4, 1, 2, 7, 1, 3, 5, 3, 0, 3, 3, 3, 2, 1, 3, 0, 3,
#        3, 2, 3, 4, 4, 1, 3, 7, 8, 2, 2, 1, 5, 7, 3, 1, 2, 3, 4, 6, 4, 4,
#        5, 1, 6, 2, 5, 4, 3, 1, 3, 5, 2, 3, 4, 1, 3, 6, 6, 2, 1, 4, 1, 6,
#        4, 3, 0, 1, 2, 3, 4, 2, 1, 2, 3, 3, 9, 3, 2, 6, 4, 5, 5, 5, 0, 3,
#        2, 5, 2, 4, 4, 2, 2, 2, 3, 5, 4, 4, 2, 2, 3, 3, 4, 2, 3, 5, 3, 1,
#        5, 2, 3, 4, 1, 3, 1, 3, 8, 8, 4, 3, 3, 4, 5, 3, 3, 4, 2, 5, 2, 3,
#        2, 2, 1, 3, 3, 3, 7, 1, 3, 1, 3, 5, 5, 2, 4, 2, 4, 0, 4, 4, 3, 4,
#        3, 2, 2, 2, 1, 1, 4, 3, 3, 4, 1, 3, 4, 4, 3, 3, 3, 3, 4, 6, 3, 0,
#        3, 2, 2, 2, 5, 5, 1, 3, 3, 3, 0, 0, 2, 5, 1, 2, 1, 2, 4, 3, 6, 1,
#        4, 1, 5, 4, 4, 5, 4, 4, 7, 4])

# %%
results.mean()
# Out:
# 3.028

# %%
results.var()
# Out:
# 2.9312160000000005

# %%
check = np.random.poisson(3, 1000)

# %%
check.mean()
# Out:
# 3.064

# %%
check.var()
# Out:
# 2.8659039999999996

# %%
check = np.random.binomial(4, 1/4, 10000)

# %%
sum(check == 4) / 10000
# Out:
# 0.0041
